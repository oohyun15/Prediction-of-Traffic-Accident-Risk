# %% [markdown]
# # Prediction of Traffic Accident Risk
# Team 7: 어서오십쇼HUMAN
# Editor: 허윤행, 김용현
# ## 1. Preprocess

# %%
# 사전 준비
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings

plt.style.use('seaborn')
sns.set(font_scale=2.5)

warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
sample = pd.read_csv('../input/TAAS_data.csv')

print("sample.shape:", sample.shape)

# 초기 샘플 데이터
sample
# Out:
# sample.shape: (72049, 13)
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별  가해자나이 요일   가해차종 노면상태  \
# 6        경상   특이사항 없음   맑음   8.0    여성   27.0  목  125cc   건조
# 8        경상   특이사항 없음   맑음   1.0    남성   24.0  목    자가용   건조
# 14       경상   특이사항 없음   맑음   1.0    여성   23.0  수    자가용   건조
# 25       경상   특이사항 없음   맑음   8.0    여성   48.0  토    자가용   건조
# 26       경상   특이사항 없음   맑음   7.0    여성   47.0  목    자가용   건조
# ...     ...       ...  ...   ...   ...    ... ..    ...  ...
# 285297   경상   특이사항 없음   맑음  12.0    여성   50.0  화    자가용   젖음
# 285307   경상   특이사항 없음   맑음  11.0    여성   24.0  수    자가용   젖음
# 285312   경상   특이사항 없음    비   7.0    여성   75.0  토    자가용   젖음
# 285313   경상   특이사항 없음    비   4.0    남성   20.0  토    자가용   젖음
# 285314   경상   특이사항 없음    비   4.0    남성   20.0  토    자가용   젖음
#
#                    보행자이동   빛 세기     사고 위치 사고 시 통제 방법
# 6                보행자가 아님  기타/불명  비어있는 교차로        신호등
# 8       표지판 무시 운전자 주변 사고     밝음   교차로 접근로        신호등
# 14               보행자가 아님     밝음       위험로      일방 통행
# 25               보행자가 아님     밝음       위험로      일방 통행
# 26      운전자 정면에서 보행 중 사고     밝음       위험로      일방 통행
# ...                  ...    ...       ...        ...
# 285297         운전자 주변 사고  조명 있음   교차로 접근로      일방 통행
# 285307           보행자가 아님     밝음       위험로      일방 통행
# 285312           보행자가 아님     밝음   교차로 접근로      일방 통행
# 285313           보행자가 아님     밝음   경사로 진입로      일방 통행
# 285314           보행자가 아님     밝음   경사로 진입로      일방 통행
#
# [72049 rows x 13 columns]

# %% [markdown]
# # 2. 결측값 제거

# %%
# 제거해주세용

# %% [markdown]
# # 3. label 변경

# %%
## 범주형 데이터 -> 수치형 데이터
# 사고내용
Target = {1: "사망", 2 : "중상", 3 : "경상"}

for label in Target:
    sample['사고내용'] = np.where(sample['사고내용'] == Target[label], label, sample['사고내용'])


# 사고 시 특이사항
Detail = {0: "특이사항 없음", 1 : "신호등 꺼짐 상태", 2 : "신호등 이상", 3: "보행자 신호", 4: "인도 위 사고", 5: "노면상태 결함", 6: "미끄러움", 7: "질퍽한 도로"}

for label in Detail:
    sample['사고 시 특이사항'] = np.where(sample['사고 시 특이사항'] == Detail[label], label, sample['사고 시 특이사항'])

# 기상 상태
Weather = {1 : "맑음", 2 : "비", 3: "눈", 4: "바람", 5: "폭풍우", 6: "눈보라", 7: "안개", 8: "기타", 9: "불명"}

for label in Weather:
    sample['기상상태'] = np.where(sample['기상상태'] == Weather[label], label, sample['기상상태'])

# 가해자성별
Sex = {1: "남성", 2: "여성"}

for label in Sex:
    sample['가해자성별'] = np.where(sample['가해자성별'] == Sex[label], label, sample['가해자성별'])

# 가해차종
CarType = {1: '자전거',2: '50cc', 3: '125cc', 4:'500cc', 5: '500cc 이상',8: '택시',9: '자가용',10: '승합차',11: '버스', 16: '기타', 17: '농기계', 18: '트럭', 19: '3.5t급 미만', 20: '7.5t급 미만', 21: '7.5t급 이상', 22: '스쿠터',23: '전기차'}

for label in CarType:
    sample['가해차종'] = np.where(sample['가해차종'] == CarType[label], label, sample['가해차종'])
    
# 노면상태
RoadState = {1: '건조',2: '젖음',3: '눈',4: '얼음',5: '3cm이상 물에 잠김',6: '미끄러움',7: '질퍽한 도로'}

for label in RoadState:
    sample['노면상태'] = np.where(sample['노면상태'] == RoadState[label], label, sample['노면상태'])

# 빛 세기
Light = {1:'밝음',4: '조명 있음', 5: '어두움',6: '조명 없음',7: '기타/불명'}

for label in Light:
    sample['빛 세기'] = np.where(sample['빛 세기'] == Light[label], label, sample['빛 세기'])

# 사고 시 통제 방법

Control = {0: '20m내에 교차로 없음', 1: '교통 정리 경찰',2: '신호등',3: '정지 신호',4: '일방 통행'}
for label in Control:
    sample['사고 시 통제 방법'] = np.where(sample['사고 시 통제 방법'] == Control[label], label, sample['사고 시 통제 방법'])

sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별  가해자나이 요일 가해차종 노면상태             보행자이동  \
# 6         3         0    1   8.0     2   27.0  목    3    1           보행자가 아님
# 8         3         0    1   1.0     1   24.0  목    9    1  표지판 무시 운전자 주변 사고
# 14        3         0    1   1.0     2   23.0  수    9    1           보행자가 아님
# 25        3         0    1   8.0     2   48.0  토    9    1           보행자가 아님
# 26        3         0    1   7.0     2   47.0  목    9    1  운전자 정면에서 보행 중 사고
# ...     ...       ...  ...   ...   ...    ... ..  ...  ...               ...
# 285297    3         0    1  12.0     2   50.0  화    9    2         운전자 주변 사고
# 285307    3         0    1  11.0     2   24.0  수    9    2           보행자가 아님
# 285312    3         0    2   7.0     2   75.0  토    9    2           보행자가 아님
# 285313    3         0    2   4.0     1   20.0  토    9    2           보행자가 아님
# 285314    3         0    2   4.0     1   20.0  토    9    2           보행자가 아님
#
#        빛 세기     사고 위치 사고 시 통제 방법
# 6         7  비어있는 교차로          2
# 8         1   교차로 접근로          2
# 14        1       위험로          4
# 25        1       위험로          4
# 26        1       위험로          4
# ...     ...       ...        ...
# 285297    4   교차로 접근로          4
# 285307    1       위험로          4
# 285312    1   교차로 접근로          4
# 285313    1   경사로 진입로          4
# 285314    1   경사로 진입로          4
#
# [72049 rows x 13 columns]

# %%
## 범주형 데이터 -> 원핫 인코딩
# To Do List:
# 요일, 보행자이동, 사고 위치

# %% [markdown]
# # 3. logarithm 함수 써서 정규화(나이)

# %%
# 코드 복붙 예정

# %% [markdown]
# # 4. 상관관계 분석

# %%
# ~

# %% [markdown]
# # 5. 시각화

# %%
# ~

# %% [markdown]
# # 6. 데이터 저장

# %%
# sample.to_csv('../input/final.csv', encoding='utf-8-sig',index_label=False)
