# %% [markdown]
# # Prediction of Traffic Accident Risk
# Team 7: 어서오십쇼HUMAN
# Editor: 허윤행, 김용현
# ## 1. Preprocess

# %%
# 사전 준비
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings

plt.style.use('seaborn')
sns.set(font_scale=2.5)

warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
sample = pd.read_csv('../input/TAAS_data.csv')

print("sample.shape:", sample.shape)

# 초기 샘플 데이터
sample
# Out:
# sample.shape: (283011, 13)
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 요일      가해차종 노면상태      보행자이동  \
# 0        경상   특이사항 없음   맑음  11.0    남성  45.0  월       자가용   건조         불명
# 1        경상   특이사항 없음   맑음   1.0    여성  25.0  토       자가용   건조         불명
# 2        경상   특이사항 없음   맑음    불명    남성  51.0  토       자가용   건조    보행자가 아님
# 3        경상   특이사항 없음   맑음   1.0    남성  50.0  수  7.5t급 미만   건조  운전자 주변 사고
# 4        경상   특이사항 없음   맑음    불명    남성  27.0  금       자가용   건조         불명
# ...     ...       ...  ...   ...   ...   ... ..       ...  ...        ...
# 285326   경상   특이사항 없음    눈   1.0    남성  57.0  목       자가용   얼음         불명
# 285327   경상   특이사항 없음    눈    불명    남성  19.0  목       자가용   얼음    보행자가 아님
# 285328   경상   특이사항 없음    눈   5.0    남성    불명  목       자가용   얼음         불명
# 285329   경상   특이사항 없음    눈  15.0    남성  29.0  목       자가용   얼음    보행자가 아님
# 285330   경상   특이사항 없음    눈  12.0    여성  17.0  목       자가용   얼음    보행자가 아님
#
#          빛 세기         사고 위치 사고 시 통제 방법
# 0          밝음           위험로      일방 통행
# 1          밝음           위험로        신호등
# 2          밝음           위험로        신호등
# 3          밝음  20m내에 교차로 없음         불명
# 4          밝음       교차로 접근로      일방 통행
# ...       ...           ...        ...
# 285326  조명 없음  20m내에 교차로 없음         불명
# 285327  조명 없음  20m내에 교차로 없음         불명
# 285328  조명 없음  20m내에 교차로 없음         불명
# 285329  조명 없음  20m내에 교차로 없음         불명
# 285330  조명 없음  20m내에 교차로 없음         불명
#
# [283011 rows x 13 columns]

# %% [markdown]
# # 2. 결측값 제거

# %%
# 제거해주세용 - 바로 진행합니다~
sample.replace('불명',np.nan,inplace = True)
sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 요일      가해차종 노면상태      보행자이동  \
# 0        경상   특이사항 없음   맑음  11.0    남성  45.0  월       자가용   건조        NaN
# 1        경상   특이사항 없음   맑음   1.0    여성  25.0  토       자가용   건조        NaN
# 2        경상   특이사항 없음   맑음   NaN    남성  51.0  토       자가용   건조    보행자가 아님
# 3        경상   특이사항 없음   맑음   1.0    남성  50.0  수  7.5t급 미만   건조  운전자 주변 사고
# 4        경상   특이사항 없음   맑음   NaN    남성  27.0  금       자가용   건조        NaN
# ...     ...       ...  ...   ...   ...   ... ..       ...  ...        ...
# 285326   경상   특이사항 없음    눈   1.0    남성  57.0  목       자가용   얼음        NaN
# 285327   경상   특이사항 없음    눈   NaN    남성  19.0  목       자가용   얼음    보행자가 아님
# 285328   경상   특이사항 없음    눈   5.0    남성   NaN  목       자가용   얼음        NaN
# 285329   경상   특이사항 없음    눈  15.0    남성  29.0  목       자가용   얼음    보행자가 아님
# 285330   경상   특이사항 없음    눈  12.0    여성  17.0  목       자가용   얼음    보행자가 아님
#
#          빛 세기         사고 위치 사고 시 통제 방법
# 0          밝음           위험로      일방 통행
# 1          밝음           위험로        신호등
# 2          밝음           위험로        신호등
# 3          밝음  20m내에 교차로 없음        NaN
# 4          밝음       교차로 접근로      일방 통행
# ...       ...           ...        ...
# 285326  조명 없음  20m내에 교차로 없음        NaN
# 285327  조명 없음  20m내에 교차로 없음        NaN
# 285328  조명 없음  20m내에 교차로 없음        NaN
# 285329  조명 없음  20m내에 교차로 없음        NaN
# 285330  조명 없음  20m내에 교차로 없음        NaN
#
# [283011 rows x 13 columns]

# %%
sample.isnull().sum()
# Out:
# 사고내용               0
# 사고 시 특이사항        208
# 기상상태            4642
# 차량년식           86346
# 가해자성별          16320
# 가해자나이          29766
# 요일                 0
# 가해차종              58
# 노면상태             530
# 보행자이동         102814
# 빛 세기            3661
# 사고 위치             67
# 사고 시 통제 방법    111765
# dtype: int64

# %%
sample = sample.dropna()
sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 요일 가해차종 노면상태             보행자이동  \
# 8        경상   특이사항 없음   맑음   1.0    남성  24.0  목  자가용   건조  표지판 무시 운전자 주변 사고
# 14       경상   특이사항 없음   맑음   1.0    여성  23.0  수  자가용   건조           보행자가 아님
# 25       경상   특이사항 없음   맑음   8.0    여성  48.0  토  자가용   건조           보행자가 아님
# 26       경상   특이사항 없음   맑음   7.0    여성  47.0  목  자가용   건조  운전자 정면에서 보행 중 사고
# 28       경상   특이사항 없음   맑음   7.0    남성  41.0  수  자가용   건조           보행자가 아님
# ...     ...       ...  ...   ...   ...   ... ..  ...  ...               ...
# 285297   경상   특이사항 없음   맑음  12.0    여성  50.0  화  자가용   젖음         운전자 주변 사고
# 285307   경상   특이사항 없음   맑음  11.0    여성  24.0  수  자가용   젖음           보행자가 아님
# 285312   경상   특이사항 없음    비   7.0    여성  75.0  토  자가용   젖음           보행자가 아님
# 285313   경상   특이사항 없음    비   4.0    남성  20.0  토  자가용   젖음           보행자가 아님
# 285314   경상   특이사항 없음    비   4.0    남성  20.0  토  자가용   젖음           보행자가 아님
#
#          빛 세기    사고 위치 사고 시 통제 방법
# 8          밝음  교차로 접근로        신호등
# 14         밝음      위험로      일방 통행
# 25         밝음      위험로      일방 통행
# 26         밝음      위험로      일방 통행
# 28         밝음      위험로      일방 통행
# ...       ...      ...        ...
# 285297  조명 있음  교차로 접근로      일방 통행
# 285307     밝음      위험로      일방 통행
# 285312     밝음  교차로 접근로      일방 통행
# 285313     밝음  경사로 진입로      일방 통행
# 285314     밝음  경사로 진입로      일방 통행
#
# [69149 rows x 13 columns]

# %%
#기타/불명 -> 불명으로 변경 후 삭제 데이터 7만 얼마에서 69000대로 줄어든 거 확인!!!!

# %% [markdown]
# # 3. label 변경

# %%
## 범주형 데이터 -> 수치형 데이터
# 사고내용
Target = {1: "사망", 2 : "중상", 3 : "경상"}

for label in Target:
    sample['사고내용'] = np.where(sample['사고내용'] == Target[label], label, sample['사고내용'])


# 사고 시 특이사항
Detail = {0: "특이사항 없음", 1: "신호등 꺼짐상태", 2: "신호등 이상", 3: "보행자 신호", 4: "인도 위 사고", 5: "노면상태 결함", 6: "미끄러움", 7: "질퍽한 도로"}

for label in Detail:
    sample['사고 시 특이사항'] = np.where(sample['사고 시 특이사항'] == Detail[label], label, sample['사고 시 특이사항'])

# 기상 상태
Weather = {1 : "맑음", 2 : "비", 3: "눈", 4: "바람", 5: "폭풍우", 6: "눈보라", 7: "안개", 8: "기타", 9: "불명"}

for label in Weather:
    sample['기상상태'] = np.where(sample['기상상태'] == Weather[label], label, sample['기상상태'])

# 가해자성별
Sex = {1: "남성", 2: "여성"}

for label in Sex:
    sample['가해자성별'] = np.where(sample['가해자성별'] == Sex[label], label, sample['가해자성별'])

# 가해차종
CarType = {1: '자전거',2: '50cc', 3: '125cc', 4:'500cc', 5: '500cc 이상',8: '택시',9: '자가용',10: '승합차',11: '버스', 16: '기타', 17: '농기계', 18: '트럭', 19: '3.5t급 미만', 20: '7.5t급 미만', 21: '7.5t급 이상', 22: '스쿠터',23: '전기차'}

for label in CarType:
    sample['가해차종'] = np.where(sample['가해차종'] == CarType[label], label, sample['가해차종'])
    
# 노면상태
RoadState = {1: '건조',2: '젖음',3: '눈',4: '얼음',5: '3cm이상 물에 잠김',6: '미끄러움',7: '질퍽한 도로'}

for label in RoadState:
    sample['노면상태'] = np.where(sample['노면상태'] == RoadState[label], label, sample['노면상태'])

# 빛 세기
Light = {1:'밝음',4: '조명 있음', 5: '어두움',6: '조명 없음',7: '기타/불명'}

for label in Light:
    sample['빛 세기'] = np.where(sample['빛 세기'] == Light[label], label, sample['빛 세기'])

# 사고 시 통제 방법

Control = {0: '20m내에 교차로 없음', 1: '교통 정리 경찰',2: '신호등',3: '정지 신호',4: '일방 통행'}
for label in Control:
    sample['사고 시 통제 방법'] = np.where(sample['사고 시 통제 방법'] == Control[label], label, sample['사고 시 통제 방법'])
JunLocation = { 0 : '20m내에 교차로 없음',1 : '교차로 접근로',2 : '비어있는 교차로',3 : '회전교차로 출구',4 : '회전 교차로 입구',5 : '주 도로 출구',6 : '주 도로 입구',7 : '경사로 진입로',8 : '위험로'}
for label in JunLocation:
    sample['사고 위치'] = np.where(sample['사고 위치'] == JunLocation[label],label,sample['사고 위치'])
sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 요일 가해차종 노면상태             보행자이동  \
# 8         3         0    1   1.0     1  24.0  목    9    1  표지판 무시 운전자 주변 사고
# 14        3         0    1   1.0     2  23.0  수    9    1           보행자가 아님
# 25        3         0    1   8.0     2  48.0  토    9    1           보행자가 아님
# 26        3         0    1   7.0     2  47.0  목    9    1  운전자 정면에서 보행 중 사고
# 28        3         0    1   7.0     1  41.0  수    9    1           보행자가 아님
# ...     ...       ...  ...   ...   ...   ... ..  ...  ...               ...
# 285297    3         0    1  12.0     2  50.0  화    9    2         운전자 주변 사고
# 285307    3         0    1  11.0     2  24.0  수    9    2           보행자가 아님
# 285312    3         0    2   7.0     2  75.0  토    9    2           보행자가 아님
# 285313    3         0    2   4.0     1  20.0  토    9    2           보행자가 아님
# 285314    3         0    2   4.0     1  20.0  토    9    2           보행자가 아님
#
#        빛 세기 사고 위치 사고 시 통제 방법
# 8         1     1          2
# 14        1     8          4
# 25        1     8          4
# 26        1     8          4
# 28        1     8          4
# ...     ...   ...        ...
# 285297    4     1          4
# 285307    1     8          4
# 285312    1     1          4
# 285313    1     7          4
# 285314    1     7          4
#
# [69149 rows x 13 columns]

# %%
## 범주형 데이터 -> 원핫 인코딩
# To Do List:
# 요일, 보행자이동, 사고 위치
sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 요일 가해차종 노면상태             보행자이동  \
# 8         3         0    1   1.0     1  24.0  목    9    1  표지판 무시 운전자 주변 사고
# 14        3         0    1   1.0     2  23.0  수    9    1           보행자가 아님
# 25        3         0    1   8.0     2  48.0  토    9    1           보행자가 아님
# 26        3         0    1   7.0     2  47.0  목    9    1  운전자 정면에서 보행 중 사고
# 28        3         0    1   7.0     1  41.0  수    9    1           보행자가 아님
# ...     ...       ...  ...   ...   ...   ... ..  ...  ...               ...
# 285297    3         0    1  12.0     2  50.0  화    9    2         운전자 주변 사고
# 285307    3         0    1  11.0     2  24.0  수    9    2           보행자가 아님
# 285312    3         0    2   7.0     2  75.0  토    9    2           보행자가 아님
# 285313    3         0    2   4.0     1  20.0  토    9    2           보행자가 아님
# 285314    3         0    2   4.0     1  20.0  토    9    2           보행자가 아님
#
#        빛 세기 사고 위치 사고 시 통제 방법
# 8         1     1          2
# 14        1     8          4
# 25        1     8          4
# 26        1     8          4
# 28        1     8          4
# ...     ...   ...        ...
# 285297    4     1          4
# 285307    1     8          4
# 285312    1     1          4
# 285313    1     7          4
# 285314    1     7          4
#
# [69149 rows x 13 columns]

# %%
sample = pd.get_dummies(sample,columns=['요일'],prefix=['요일'])
sample = pd.get_dummies(sample,columns=['보행자이동'],prefix=['보행자이동'])
sample
# Out:
#        사고내용 사고 시 특이사항 기상상태  차량년식 가해자성별 가해자나이 가해차종 노면상태 빛 세기 사고 위치  ... 요일_화  \
# 8         3         0    1   1.0     1  24.0    9    1    1     1  ...    0
# 14        3         0    1   1.0     2  23.0    9    1    1     8  ...    0
# 25        3         0    1   8.0     2  48.0    9    1    1     8  ...    0
# 26        3         0    1   7.0     2  47.0    9    1    1     8  ...    0
# 28        3         0    1   7.0     1  41.0    9    1    1     8  ...    0
# ...     ...       ...  ...   ...   ...   ...  ...  ...  ...   ...  ...  ...
# 285297    3         0    1  12.0     2  50.0    9    2    4     1  ...    1
# 285307    3         0    1  11.0     2  24.0    9    2    1     8  ...    0
# 285312    3         0    2   7.0     2  75.0    9    2    1     1  ...    0
# 285313    3         0    2   4.0     1  20.0    9    2    1     7  ...    0
# 285314    3         0    2   4.0     1  20.0    9    2    1     7  ...    0
#
#         보행자이동_교차로에서 보행 중 사고  보행자이동_교차로에서 사고  보행자이동_교차로에서 역 방향 보행 중 사고  \
# 8                         0               0                         0
# 14                        0               0                         0
# 25                        0               0                         0
# 26                        0               0                         0
# 28                        0               0                         0
# ...                     ...             ...                       ...
# 285297                    0               0                         0
# 285307                    0               0                         0
# 285312                    0               0                         0
# 285313                    0               0                         0
# 285314                    0               0                         0
#
#         보행자이동_교차로에서 표지판 무시 운전자 사고  보행자이동_보행자가 아님  보행자이동_운전자 정면에서 보행 중 사고  \
# 8                               0              0                       0
# 14                              0              1                       0
# 25                              0              1                       0
# 26                              0              0                       1
# 28                              0              1                       0
# ...                           ...            ...                     ...
# 285297                          0              0                       0
# 285307                          0              1                       0
# 285312                          0              1                       0
# 285313                          0              1                       0
# 285314                          0              1                       0
#
#         보행자이동_운전자 주변 사고  보행자이동_표지판 무시 운전자 정면 사고  보행자이동_표지판 무시 운전자 주변 사고
# 8                     0                       0                       1
# 14                    0                       0                       0
# 25                    0                       0                       0
# 26                    0                       0                       0
# 28                    0                       0                       0
# ...                 ...                     ...                     ...
# 285297                1                       0                       0
# 285307                0                       0                       0
# 285312                0                       0                       0
# 285313                0                       0                       0
# 285314                0                       0                       0
#
# [69149 rows x 27 columns]

# %%
sample.dtypes
# Out:
# 사고내용                         object
# 사고 시 특이사항                    object
# 기상상태                         object
# 차량년식                         object
# 가해자성별                        object
# 가해자나이                        object
# 가해차종                         object
# 노면상태                         object
# 빛 세기                         object
# 사고 위치                        object
# 사고 시 통제 방법                   object
# 요일_금                          uint8
# 요일_목                          uint8
# 요일_수                          uint8
# 요일_월                          uint8
# 요일_일                          uint8
# 요일_토                          uint8
# 요일_화                          uint8
# 보행자이동_교차로에서 보행 중 사고           uint8
# 보행자이동_교차로에서 사고                uint8
# 보행자이동_교차로에서 역 방향 보행 중 사고      uint8
# 보행자이동_교차로에서 표지판 무시 운전자 사고     uint8
# 보행자이동_보행자가 아님                 uint8
# 보행자이동_운전자 정면에서 보행 중 사고        uint8
# 보행자이동_운전자 주변 사고               uint8
# 보행자이동_표지판 무시 운전자 정면 사고        uint8
# 보행자이동_표지판 무시 운전자 주변 사고        uint8
# dtype: object

# %%
#object 형태에서 int형으로 통일하기 위한 작업
#우선 float형태가 있기 때문에 float로 갔다가 int로 변경
sample = sample.astype('float')
sample = sample.astype('int')
sample.dtypes
# Out:
# 사고내용                         int32
# 사고 시 특이사항                    int32
# 기상상태                         int32
# 차량년식                         int32
# 가해자성별                        int32
# 가해자나이                        int32
# 가해차종                         int32
# 노면상태                         int32
# 빛 세기                         int32
# 사고 위치                        int32
# 사고 시 통제 방법                   int32
# 요일_금                         int32
# 요일_목                         int32
# 요일_수                         int32
# 요일_월                         int32
# 요일_일                         int32
# 요일_토                         int32
# 요일_화                         int32
# 보행자이동_교차로에서 보행 중 사고          int32
# 보행자이동_교차로에서 사고               int32
# 보행자이동_교차로에서 역 방향 보행 중 사고     int32
# 보행자이동_교차로에서 표지판 무시 운전자 사고    int32
# 보행자이동_보행자가 아님                int32
# 보행자이동_운전자 정면에서 보행 중 사고       int32
# 보행자이동_운전자 주변 사고              int32
# 보행자이동_표지판 무시 운전자 정면 사고       int32
# 보행자이동_표지판 무시 운전자 주변 사고       int32
# dtype: object

# %%
sample
# Out:
#         사고내용  사고 시 특이사항  기상상태  차량년식  가해자성별  가해자나이  가해차종  노면상태  빛 세기  사고 위치  \
# 8          3          0     1     1      1     24     9     1     1      1
# 14         3          0     1     1      2     23     9     1     1      8
# 25         3          0     1     8      2     48     9     1     1      8
# 26         3          0     1     7      2     47     9     1     1      8
# 28         3          0     1     7      1     41     9     1     1      8
# ...      ...        ...   ...   ...    ...    ...   ...   ...   ...    ...
# 285297     3          0     1    12      2     50     9     2     4      1
# 285307     3          0     1    11      2     24     9     2     1      8
# 285312     3          0     2     7      2     75     9     2     1      1
# 285313     3          0     2     4      1     20     9     2     1      7
# 285314     3          0     2     4      1     20     9     2     1      7
#
#         ...  요일_화  보행자이동_교차로에서 보행 중 사고  보행자이동_교차로에서 사고  \
# 8       ...     0                    0               0
# 14      ...     0                    0               0
# 25      ...     0                    0               0
# 26      ...     0                    0               0
# 28      ...     0                    0               0
# ...     ...   ...                  ...             ...
# 285297  ...     1                    0               0
# 285307  ...     0                    0               0
# 285312  ...     0                    0               0
# 285313  ...     0                    0               0
# 285314  ...     0                    0               0
#
#         보행자이동_교차로에서 역 방향 보행 중 사고  보행자이동_교차로에서 표지판 무시 운전자 사고  보행자이동_보행자가 아님  \
# 8                              0                          0              0
# 14                             0                          0              1
# 25                             0                          0              1
# 26                             0                          0              0
# 28                             0                          0              1
# ...                          ...                        ...            ...
# 285297                         0                          0              0
# 285307                         0                          0              1
# 285312                         0                          0              1
# 285313                         0                          0              1
# 285314                         0                          0              1
#
#         보행자이동_운전자 정면에서 보행 중 사고  보행자이동_운전자 주변 사고  보행자이동_표지판 무시 운전자 정면 사고  \
# 8                            0                0                       0
# 14                           0                0                       0
# 25                           0                0                       0
# 26                           1                0                       0
# 28                           0                0                       0
# ...                        ...              ...                     ...
# 285297                       0                1                       0
# 285307                       0                0                       0
# 285312                       0                0                       0
# 285313                       0                0                       0
# 285314                       0                0                       0
#
#         보행자이동_표지판 무시 운전자 주변 사고
# 8                            1
# 14                           0
# 25                           0
# 26                           0
# 28                           0
# ...                        ...
# 285297                       0
# 285307                       0
# 285312                       0
# 285313                       0
# 285314                       0
#
# [69149 rows x 27 columns]

# %% [markdown]
# # 3. logarithm 함수 써서 정규화(나이)

# %%
# 코드 복붙 예정

# %% [markdown]
# # 4. 상관관계 분석

# %%
# ~

# %% [markdown]
# # 5. 시각화

# %%
# ~

# %% [markdown]
# # 6. 데이터 저장

# %%
# sample.to_csv('../input/final.csv', encoding='utf-8-sig',index_label=False)
